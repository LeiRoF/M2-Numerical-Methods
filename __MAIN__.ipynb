# %%
import bulk_simulation

# %% [markdown]
# ---

# %% [markdown]
# # Config

# %%
L = 50 # Size of the grid
D1 = 1e4 # Diffusion coefficient [s-1]
F = 1e4 # linspace(5e-6,1e4,1000,endpoint=True) # Flux [s-1]

# Starting monomers
N = 0 # L**2 / 100

steps = 1000

number_of_simulations = 100

# %% [markdown]
# ---

# %% [markdown]
# # Simulations

# %%
bulk_simulation.run("iteration", L, D1, F, N, steps, number_of_simulations)
# Out:
# Bulk simulation time: 1.81394362449646s
# <Process name='Process-1' pid=16644 parent=8864 stopped exitcode=1>
# Generating plots ╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1% 1/100 0:00:00 eta -
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\vince\Documents\Dev\CompuPhys\M2-Numerical-Methods\__MAIN__.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vince/Documents/Dev/CompuPhys/M2-Numerical-Methods/__MAIN__.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> bulk_simulation.run("iteration", L, D1, F, N, steps, number_of_simulations)
#
# File c:\Users\vince\Documents\Dev\CompuPhys\M2-Numerical-Methods\bulk_simulation.py:106, in run(mode, L, D1, F, N, steps, number_of_simulations)
#      99         by = arange(steps)
#     101     # Plotting data for each simulation
#     102     multiplot.record(
#     103         L = L,
#     104         by = by,
#     105         by_name = mode,
# --> 106         monomers = res[i].monomers,
#     107         free_monomers = res[i].free_monomers,
#     108         stuck_monomers = res[i].stuck_monomers,
#     109         occuped_space = res[i].occuped_space,
#     110         islands = res[i].islands,
#     111         visited_sites = res[i].visited_sites,
#     112         average_displacements = res[i].average_displacements,
#     113         a = res[i].a,
#     114         b = res[i].b,
#     115         c = res[i].c,
#     116         d = res[i].d,
#     117         ah = res[i].ah,
#     118         k1 = res[i].k1,
#     119         k2 = res[i].k2,
#     120         k3 = res[i].k3,
#     121         alpha = 0.01,
#     122         simu = i+1 if number_of_simulations > 1 else i
#     123     )
#     125 # Plotting average of data
#     126 multiplot.record(
#     127     L = L,
#     128     by = by,
#    (...)
#     146     simu = 0
#     147 )
#
# NameError: name 'res' is not defined

# %%
bulk_simulation.run("density", L, D1, F, N, steps, number_of_simulations)
